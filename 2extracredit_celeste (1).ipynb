# %%
import matplotlib.pyplot as plt

# %%
VIS7_MEAN = 244.5
AUD7_MEAN = 186
VIS7_STD = 23.37
AUD7_STD = 48.43

# %%
plt.bar(['Person 7 Visual', 'Person 7 Auditory'],[VIS7_MEAN, AUD7_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')
